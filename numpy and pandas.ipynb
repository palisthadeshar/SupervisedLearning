# %%
import numpy as np

# %%
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20221116",periods=5)

# %%
dates
# Out:
# DatetimeIndex(['2022-11-16', '2022-11-17', '2022-11-18', '2022-11-19',
#                '2022-11-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(5,4),index=dates,columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2022-11-16  1.066520  1.839266  0.482068  0.228045
# 2022-11-17  0.282633 -0.832107 -0.285544  0.771680
# 2022-11-18 -1.668632  0.137766 -0.530869 -1.549287
# 2022-11-19 -2.160704  0.509648  1.081395  2.187018
# 2022-11-20  0.423578  0.143147  1.642376  0.509322

# %%
df.at[dates[2],"A"]
# Out:
# -1.6686319285449482

# %%
df.loc["20221119",["A","D"]]
# Out:
# A   -2.160704
# D    2.187018
# Name: 2022-11-19 00:00:00, dtype: float64

# %%
df.iloc[1:4,0:3] #rows and colums defination
# Out:
#                    A         B         C
# 2022-11-17  0.282633 -0.832107 -0.285544
# 2022-11-18 -1.668632  0.137766 -0.530869
# 2022-11-19 -2.160704  0.509648  1.081395

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2022-11-17  0.282633 -0.285544
# 2022-11-18 -1.668632 -0.530869
# 2022-11-20  0.423578  1.642376

# %%
df[df["B"]>0]
# Out:
#                    A         B         C         D
# 2022-11-16  1.066520  1.839266  0.482068  0.228045
# 2022-11-18 -1.668632  0.137766 -0.530869 -1.549287
# 2022-11-19 -2.160704  0.509648  1.081395  2.187018
# 2022-11-20  0.423578  0.143147  1.642376  0.509322

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2022-11-16  1.066520  1.839266  0.482068  0.228045
# 2022-11-17  0.282633       NaN       NaN  0.771680
# 2022-11-18       NaN  0.137766       NaN       NaN
# 2022-11-19       NaN  0.509648  1.081395  2.187018
# 2022-11-20  0.423578  0.143147  1.642376  0.509322

# %%
data={"A":2.0,
       "B":pd.Timestamp("20221116"),
     "C":pd.Series(1,index=list(range(5)),dtype="float32"),
     "D":np.array([2]*5,dtype="int32"),
     "E":pd.Categorical(["test","train","test","train","test"]),
     "F":"foo"}

# %%
df=pd.DataFrame(data)
df
# Out:
#      A          B    C  D      E    F
# 0  2.0 2022-11-16  1.0  2   test  foo
# 1  2.0 2022-11-16  1.0  2  train  foo
# 2  2.0 2022-11-16  1.0  2   test  foo
# 3  2.0 2022-11-16  1.0  2  train  foo
# 4  2.0 2022-11-16  1.0  2   test  foo

# %%
df.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#      A          B    C  D      E    F
# 0  2.0 2022-11-16  1.0  2   test  foo
# 1  2.0 2022-11-16  1.0  2  train  foo
# 2  2.0 2022-11-16  1.0  2   test  foo
# 3  2.0 2022-11-16  1.0  2  train  foo
# 4  2.0 2022-11-16  1.0  2   test  foo

# %%
df.tail(3)
# Out:
#      A          B    C  D      E    F
# 2  2.0 2022-11-16  1.0  2   test  foo
# 3  2.0 2022-11-16  1.0  2  train  foo
# 4  2.0 2022-11-16  1.0  2   test  foo

# %%
df.index
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[2.0, Timestamp('2022-11-16 00:00:00'), 1.0, 2, 'test', 'foo'],
#        [2.0, Timestamp('2022-11-16 00:00:00'), 1.0, 2, 'train', 'foo'],
#        [2.0, Timestamp('2022-11-16 00:00:00'), 1.0, 2, 'test', 'foo'],
#        [2.0, Timestamp('2022-11-16 00:00:00'), 1.0, 2, 'train', 'foo'],
#        [2.0, Timestamp('2022-11-16 00:00:00'), 1.0, 2, 'test', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#          A    C    D
# count  5.0  5.0  5.0
# mean   2.0  1.0  2.0
# std    0.0  0.0  0.0
# min    2.0  1.0  2.0
# 25%    2.0  1.0  2.0
# 50%    2.0  1.0  2.0
# 75%    2.0  1.0  2.0
# max    2.0  1.0  2.0

# %%
df.T
# Out:
#                      0                    1                    2  \
# A                  2.0                  2.0                  2.0
# B  2022-11-16 00:00:00  2022-11-16 00:00:00  2022-11-16 00:00:00
# C                  1.0                  1.0                  1.0
# D                    2                    2                    2
# E                 test                train                 test
# F                  foo                  foo                  foo
#
#                      3                    4
# A                  2.0                  2.0
# B  2022-11-16 00:00:00  2022-11-16 00:00:00
# C                  1.0                  1.0
# D                    2                    2
# E                train                 test
# F                  foo                  foo

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#      F      E  D    C          B    A
# 0  foo   test  2  1.0 2022-11-16  2.0
# 1  foo  train  2  1.0 2022-11-16  2.0
# 2  foo   test  2  1.0 2022-11-16  2.0
# 3  foo  train  2  1.0 2022-11-16  2.0
# 4  foo   test  2  1.0 2022-11-16  2.0

# %%
df.sort_values(by="B")
# Out:
#      A          B    C  D      E    F
# 0  2.0 2022-11-16  1.0  2   test  foo
# 1  2.0 2022-11-16  1.0  2  train  foo
# 2  2.0 2022-11-16  1.0  2   test  foo
# 3  2.0 2022-11-16  1.0  2  train  foo
# 4  2.0 2022-11-16  1.0  2   test  foo

# %%
df.at[2,'E']
# Out:
# 'test'

# %%
df["A"]
# Out:
# 0    2.0
# 1    2.0
# 2    2.0
# 3    2.0
# 4    2.0
# Name: A, dtype: float64

# %%
df[0:2]
# Out:
#      A          B    C  D      E    F
# 0  2.0 2022-11-16  1.0  2   test  foo
# 1  2.0 2022-11-16  1.0  2  train  foo

# %%
df.loc[:, ["A", "D"]]
# Out:
#      A  D
# 0  2.0  2
# 1  2.0  2
# 2  2.0  2
# 3  2.0  2
# 4  2.0  2

# %%
data={"A":2.0,
       "B":pd.date_range("20221116",periods=5),
     "C":pd.Series(1,index=list(range(5)),dtype="float32"),
     "D":np.array([2]*5,dtype="int32"),
     "E":pd.Categorical(["test","train","test","train","test"]),
     "F":"foo"}

# %%
df1=pd.DataFrame(data)
df1
# Out:
#      A          B    C  D      E    F
# 0  2.0 2022-11-16  1.0  2   test  foo
# 1  2.0 2022-11-17  1.0  2  train  foo
# 2  2.0 2022-11-18  1.0  2   test  foo
# 3  2.0 2022-11-19  1.0  2  train  foo
# 4  2.0 2022-11-20  1.0  2   test  foo

# %%
df1.loc[:, ["A", "B"]]
# Out:
#      A          B
# 0  2.0 2022-11-16
# 1  2.0 2022-11-17
# 2  2.0 2022-11-18
# 3  2.0 2022-11-19
# 4  2.0 2022-11-20

# %%
df1.loc["20221116":"20221119",["A","B"]]
# Out:
# Empty DataFrame
# Columns: [A, B]
# Index: []

# %%
df2=df1.copy()

# %%
df2["G"]=["one","two","three","four","five"]

# %%
df2
# Out:
#      A          B    C  D      E    F      G
# 0  2.0 2022-11-16  1.0  2   test  foo    one
# 1  2.0 2022-11-17  1.0  2  train  foo    two
# 2  2.0 2022-11-18  1.0  2   test  foo  three
# 3  2.0 2022-11-19  1.0  2  train  foo   four
# 4  2.0 2022-11-20  1.0  2   test  foo   five

# %%
df2[df2["G"].isin(["two","three"])] #isin()method for filtering
# Out:
#      A          B    C  D      E    F      G
# 1  2.0 2022-11-17  1.0  2  train  foo    two
# 2  2.0 2022-11-18  1.0  2   test  foo  three

# %%
s1 = pd.Series([1,2,3,4,5],index=pd.date_range("20221116",periods=5))

# %%
s1
# Out:
# 2022-11-16    1
# 2022-11-17    2
# 2022-11-18    3
# 2022-11-19    4
# 2022-11-20    5
# Freq: D, dtype: int64

# %%
df2["H"]=s1

# %%
df2
# Out:
#      A          B    C  D      E    F      G   H
# 0  2.0 2022-11-16  1.0  2   test  foo    one NaN
# 1  2.0 2022-11-17  1.0  2  train  foo    two NaN
# 2  2.0 2022-11-18  1.0  2   test  foo  three NaN
# 3  2.0 2022-11-19  1.0  2  train  foo   four NaN
# 4  2.0 2022-11-20  1.0  2   test  foo   five NaN

# %%
df2.at[dates[0],"A"]=8.0 #setting values by label

# %%
df2.iat[0,6]=9.0

# %%
df2.loc[:,"D"]=np.array([4]*len(df2))

# %%
df2
# Out:
#                        A                    B    C  D      E    F      G   H
# 0                    2.0  2022-11-16 00:00:00  1.0  4   test  foo    9.0 NaN
# 1                    2.0  2022-11-17 00:00:00  1.0  4  train  foo    two NaN
# 2                    2.0  2022-11-18 00:00:00  1.0  4   test  foo  three NaN
# 3                    2.0  2022-11-19 00:00:00  1.0  4  train  foo   four NaN
# 4                    2.0  2022-11-20 00:00:00  1.0  4   test  foo   five NaN
# 2022-11-16 00:00:00  8.0                  8.0  NaN  4    NaN  NaN    NaN NaN

# %%
df2=df.copy()

# %%
df1=df2.reindex(index=dates[0:4],columns=list(df2.columns)+["I"])

# %%
df1.loc[dates[0]:dates[1],"I"]=1

# %%
df1
# Out:
#              A    B   C   D    E    F   H    I
# 2022-11-16 NaN  NaN NaN NaN  NaN  NaN NaN  1.0
# 2022-11-17 NaN  NaN NaN NaN  NaN  NaN NaN  1.0
# 2022-11-18 NaN  NaN NaN NaN  NaN  NaN NaN  NaN
# 2022-11-19 NaN  NaN NaN NaN  NaN  NaN NaN  NaN

# %%
dfs = pd.DataFrame(np.random.randn(5, 4), index=dates, columns=list("ABCD"))

# %%
dfs
# Out:
#                    A         B         C         D
# 2022-11-16  0.332447 -1.206403  2.429521  0.054783
# 2022-11-17 -0.365711  1.958901  1.384879 -1.918327
# 2022-11-18  0.266575 -1.083759 -1.852160 -1.287450
# 2022-11-19  2.281213 -0.911452 -1.522198 -0.851692
# 2022-11-20 -0.091108 -1.805557  1.570149  0.387760

# %%
dfs1=dfs.reindex(index=dates[0:4],columns=list(dfs.columns)+["E"])

# %%
dfs1.loc[dates[1]:dates[3],"E"]=4 #adds data to missing column

# %%
dfs1
# Out:
#                    A         B         C         D    E
# 2022-11-16  0.332447 -1.206403  2.429521  0.054783  NaN
# 2022-11-17 -0.365711  1.958901  1.384879 -1.918327  4.0
# 2022-11-18  0.266575 -1.083759 -1.852160 -1.287450  4.0
# 2022-11-19  2.281213 -0.911452 -1.522198 -0.851692  4.0

# %%
dfs1.dropna(how="any") #drops any rows that have missing data
# Out:
#                    A         B         C         D    E
# 2022-11-17 -0.365711  1.958901  1.384879 -1.918327  4.0
# 2022-11-18  0.266575 -1.083759 -1.852160 -1.287450  4.0
# 2022-11-19  2.281213 -0.911452 -1.522198 -0.851692  4.0

# %%
dfs1.fillna(value=7) #fills missing data
# Out:
#                    A         B         C         D    E
# 2022-11-16  0.332447 -1.206403  2.429521  0.054783  7.0
# 2022-11-17 -0.365711  1.958901  1.384879 -1.918327  4.0
# 2022-11-18  0.266575 -1.083759 -1.852160 -1.287450  4.0
# 2022-11-19  2.281213 -0.911452 -1.522198 -0.851692  4.0

# %%
pd.isna(dfs1) #gets boolean value where values are nan
# Out:
#                 A      B      C      D      E
# 2022-11-16  False  False  False  False   True
# 2022-11-17  False  False  False  False  False
# 2022-11-18  False  False  False  False  False
# 2022-11-19  False  False  False  False  False

# %%
#operations (stats)

# %%
dfs1.mean()
# Out:
# A    0.628631
# B   -0.310678
# C    0.110011
# D   -1.000671
# E    4.000000
# dtype: float64

# %%
dfs1.mean(axis=1) #from another axis
# Out:
# 2022-11-16    0.402587
# 2022-11-17    1.011948
# 2022-11-18    0.008641
# 2022-11-19    0.599174
# Freq: D, dtype: float64

# %%
s=pd.Series([1,2,5,np.nan,8],index=dates).shift(2) #addings values from the specified shift

# %%
s
# Out:
# 2022-11-16    NaN
# 2022-11-17    NaN
# 2022-11-18    1.0
# 2022-11-19    2.0
# 2022-11-20    5.0
# Freq: D, dtype: float64

# %%
dfs.sub(s,axis="index")
# Out:
#                    A         B         C         D
# 2022-11-16       NaN       NaN       NaN       NaN
# 2022-11-17       NaN       NaN       NaN       NaN
# 2022-11-18 -0.733425 -2.083759 -2.852160 -2.287450
# 2022-11-19  0.281213 -2.911452 -3.522198 -2.851692
# 2022-11-20 -5.091108 -6.805557 -3.429851 -4.612240

# %%
dfs.apply(np.cumsum) #apllies a user defined function to the data
# Out:
#                    A         B         C         D
# 2022-11-16  0.332447 -1.206403  2.429521  0.054783
# 2022-11-17 -0.033264  0.752498  3.814400 -1.863544
# 2022-11-18  0.233311 -0.331261  1.962240 -3.150993
# 2022-11-19  2.514524 -1.242713  0.440042 -4.002685
# 2022-11-20  2.423416 -3.048270  2.010192 -3.614925

# %%
dfs.apply(lambda x:x.max() + x.min())
# Out:
# A    1.915502
# B    0.153344
# C    0.577361
# D   -1.530567
# dtype: float64

# %%
#histogramming

# %%
s=pd.Series(np.random.randint(0,7,size=10))

# %%
s
# Out:
# 0    5
# 1    3
# 2    5
# 3    6
# 4    1
# 5    5
# 6    2
# 7    4
# 8    0
# 9    5
# dtype: int32

# %%
s.value_counts()
# Out:
# 5    4
# 3    1
# 6    1
# 1    1
# 2    1
# 4    1
# 0    1
# dtype: int64

# %%
str_ = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

# %%
str_.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
d = pd.DataFrame(np.random.randn(10,5))

# %%
d
# Out:
#           0         1         2         3         4
# 0  0.306978 -0.872575  0.312324  1.127852  0.936802
# 1  2.089608 -0.172695 -0.473250  0.959509 -0.600489
# 2 -0.288093  0.959404 -2.128356  1.912321 -1.354249
# 3  0.727861 -1.915892 -1.072131  1.171787 -0.592374
# 4 -0.142042  2.076513 -0.757568  1.214266  0.242093
# 5  0.021850 -0.438235 -0.459827  0.062350 -0.677084
# 6  0.881023  0.328606  0.817175 -0.188945  0.213592
# 7 -1.165807  0.163293 -1.020250  0.740181 -0.799853
# 8  1.699805 -0.960425 -1.652682 -0.368237  1.283003
# 9 -0.107055  0.203052  0.580671 -1.097974 -1.309018

# %%
pieces=[d[:2],d[2:5],d[8:]]

# %%
pieces
# Out:
# [          0         1         2         3         4
#  0  0.306978 -0.872575  0.312324  1.127852  0.936802
#  1  2.089608 -0.172695 -0.473250  0.959509 -0.600489,
#            0         1         2         3         4
#  2 -0.288093  0.959404 -2.128356  1.912321 -1.354249
#  3  0.727861 -1.915892 -1.072131  1.171787 -0.592374
#  4 -0.142042  2.076513 -0.757568  1.214266  0.242093,
#            0         1         2         3         4
#  8  1.699805 -0.960425 -1.652682 -0.368237  1.283003
#  9 -0.107055  0.203052  0.580671 -1.097974 -1.309018]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3         4
# 0  0.306978 -0.872575  0.312324  1.127852  0.936802
# 1  2.089608 -0.172695 -0.473250  0.959509 -0.600489
# 2 -0.288093  0.959404 -2.128356  1.912321 -1.354249
# 3  0.727861 -1.915892 -1.072131  1.171787 -0.592374
# 4 -0.142042  2.076513 -0.757568  1.214266  0.242093
# 8  1.699805 -0.960425 -1.652682 -0.368237  1.283003
# 9 -0.107055  0.203052  0.580671 -1.097974 -1.309018

# %%
left=pd.DataFrame({"key":["one","Two"],"leftval":[1,2]})

# %%
right=pd.DataFrame({"key":["one","Two"],"rightval":[1,2]})

# %%
pd.merge(left,right,on="key")
# Out:
#    key  leftval  rightval
# 0  one        1         1
# 1  Two        2         2

# %%
dfs.groupby("A")[["C","D"]].sum()
# Out:
#                   C         D
# A
# -0.365711  1.384879 -1.918327
# -0.091108  1.570149  0.387760
#  0.266575 -1.852160 -1.287450
#  0.332447  2.429521  0.054783
#  2.281213 -1.522198 -0.851692

# %%
dfs.groupby(["C","D"]).sum()
# Out:
#                             A         B
# C         D
# -1.852160 -1.287450  0.266575 -1.083759
# -1.522198 -0.851692  2.281213 -0.911452
#  1.384879 -1.918327 -0.365711  1.958901
#  1.570149  0.387760 -0.091108 -1.805557
#  2.429521  0.054783  0.332447 -1.206403

# %%
stacked=d.stack()

# %%
stacked
# Out:
# 0  0    0.306978
#    1   -0.872575
#    2    0.312324
#    3    1.127852
#    4    0.936802
# 1  0    2.089608
#    1   -0.172695
#    2   -0.473250
#    3    0.959509
#    4   -0.600489
# 2  0   -0.288093
#    1    0.959404
#    2   -2.128356
#    3    1.912321
#    4   -1.354249
# 3  0    0.727861
#    1   -1.915892
#    2   -1.072131
#    3    1.171787
#    4   -0.592374
# 4  0   -0.142042
#    1    2.076513
#    2   -0.757568
#    3    1.214266
#    4    0.242093
# 5  0    0.021850
#    1   -0.438235
#    2   -0.459827
#    3    0.062350
#    4   -0.677084
# 6  0    0.881023
#    1    0.328606
#    2    0.817175
#    3   -0.188945
#    4    0.213592
# 7  0   -1.165807
#    1    0.163293
#    2   -1.020250
#    3    0.740181
#    4   -0.799853
# 8  0    1.699805
#    1   -0.960425
#    2   -1.652682
#    3   -0.368237
#    4    1.283003
# 9  0   -0.107055
#    1    0.203052
#    2    0.580671
#    3   -1.097974
#    4   -1.309018
# dtype: float64

# %%
#time_series

# %%
rng = pd.date_range("1/1/2022",periods=100,freq="S")

# %%
ts = pd.Series(np.random.randint(0,500,len(rng)),index=rng)

# %%
ts.resample("5Min").sum()
# Out:
# 2022-01-01    26038
# Freq: 5T, dtype: int32

# %%
import matplotlib.pyplot as plt

# %%
plt.close("all")

# %%
ts=pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2022",periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)


df = df.cumsum()

plt.figure();

df.plot();

plt.legend(loc='best');

# %%
car_sales=pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales["Odometer (KM)"]>20000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"]
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','').astype(int)

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23464\2847182809.py in <module>
# ----> 1 car_sales["Price"].plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     325     def generate(self):
# ...

# %%
plot=abs(car_sales["Price"])/100
plot.plot()

# %%
#manupulating data
car_sales["Make"].str.lower()

# %%
car_sales

# %%
#reassign to change the original data
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing

# %%
val=car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing.head()

# %%
car_sales_missing["Odometer"]=val

# %%
car_sales_missing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23464\3802461933.py in <module>
# ----> 1 car_sales_missing
#
# NameError: name 'car_sales_missing' is not defined

# %%
car_sales_missing.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23464\3068347217.py in <module>
# ----> 1 car_sales_missing.dropna(inplace=True)
#
# NameError: name 'car_sales_missing' is not defined

# %%
car_sales_missing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23464\3802461933.py in <module>
# ----> 1 car_sales_missing
#
# NameError: name 'car_sales_missing' is not defined

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
dropped_file=car_sales_missing.dropna()

# %%
dropped_file
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
seats_column = pd.Series([5,5,5,5,5])

# %%
car_sales["Seats"]=seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales["Seats"].fillna(5,inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
#create column from python list
fuel_economy = [3.4,5.6,6.7,7.8,7.8,5.6,5.6,4.5,7.8,7.8]
car_sales["Fuel consumption per 100KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel consumption  \
# 0  Toyota  White         150043      4   $4,000.00    5.0               3.4
# 1   Honda    Red          87899      4   $5,000.00    5.0               5.6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0               6.7
# 3     BMW  Black          11179      5  $22,000.00    5.0               7.8
# 4  Nissan  White         213095      4   $3,500.00    5.0               7.8
# 5  Toyota  Green          99213      4   $4,500.00    5.0               5.6
# 6   Honda   Blue          45698      4   $7,500.00    5.0               5.6
# 7   Honda   Blue          54738      4   $7,000.00    5.0               4.5
# 8  Toyota  White          60000      4   $6,250.00    5.0               7.8
# 9  Nissan  White          31600      4   $9,700.00    5.0               7.8
#
#    Fuel consumption per 100KM
# 0                         3.4
# 1                         5.6
# 2                         6.7
# ...

# %%
car_sales["Total fuel used"]=car_sales["Odometer (KM)"]/100 * car_sales["Fuel consumption per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel consumption  \
# 0  Toyota  White         150043      4   $4,000.00    5.0               3.4
# 1   Honda    Red          87899      4   $5,000.00    5.0               5.6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0               6.7
# 3     BMW  Black          11179      5  $22,000.00    5.0               7.8
# 4  Nissan  White         213095      4   $3,500.00    5.0               7.8
# 5  Toyota  Green          99213      4   $4,500.00    5.0               5.6
# 6   Honda   Blue          45698      4   $7,500.00    5.0               5.6
# 7   Honda   Blue          54738      4   $7,000.00    5.0               4.5
# 8  Toyota  White          60000      4   $6,250.00    5.0               7.8
# 9  Nissan  White          31600      4   $9,700.00    5.0               7.8
#
#    Fuel consumption per 100KM  Total fuel used
# 0                         3.4         5101.462
# ...

# %%
#create a column from single value
car_sales["Number of wheels"]=4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel consumption  \
# 0  Toyota  White         150043      4   $4,000.00    5.0               3.4
# 1   Honda    Red          87899      4   $5,000.00    5.0               5.6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0               6.7
# 3     BMW  Black          11179      5  $22,000.00    5.0               7.8
# 4  Nissan  White         213095      4   $3,500.00    5.0               7.8
# 5  Toyota  Green          99213      4   $4,500.00    5.0               5.6
# 6   Honda   Blue          45698      4   $7,500.00    5.0               5.6
# 7   Honda   Blue          54738      4   $7,000.00    5.0               4.5
# 8  Toyota  White          60000      4   $6,250.00    5.0               7.8
# 9  Nissan  White          31600      4   $9,700.00    5.0               7.8
#
#    Fuel consumption per 100KM  Total fuel used  Number of wheels
# 0                         3.4         5101.462                 4
# ...

# %%
car_sales["Passed Road Saftey"]=True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel consumption  \
# 0  Toyota  White         150043      4   $4,000.00    5.0               3.4
# 1   Honda    Red          87899      4   $5,000.00    5.0               5.6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0               6.7
# 3     BMW  Black          11179      5  $22,000.00    5.0               7.8
# 4  Nissan  White         213095      4   $3,500.00    5.0               7.8
# 5  Toyota  Green          99213      4   $4,500.00    5.0               5.6
# 6   Honda   Blue          45698      4   $7,500.00    5.0               5.6
# 7   Honda   Blue          54738      4   $7,000.00    5.0               4.5
# 8  Toyota  White          60000      4   $6,250.00    5.0               7.8
# 9  Nissan  White          31600      4   $9,700.00    5.0               7.8
#
#    Fuel consumption per 100KM  Total fuel used  Number of wheels  \
# 0                         3.4         5101.462                 4
# ...

# %%
car_sales=car_sales.drop("Seats",axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel consumption  \
# 0  Toyota  White         150043      4   $4,000.00               3.4
# 1   Honda    Red          87899      4   $5,000.00               5.6
# 2  Toyota   Blue          32549      3   $7,000.00               6.7
# 3     BMW  Black          11179      5  $22,000.00               7.8
# 4  Nissan  White         213095      4   $3,500.00               7.8
# 5  Toyota  Green          99213      4   $4,500.00               5.6
# 6   Honda   Blue          45698      4   $7,500.00               5.6
# 7   Honda   Blue          54738      4   $7,000.00               4.5
# 8  Toyota  White          60000      4   $6,250.00               7.8
# 9  Nissan  White          31600      4   $9,700.00               7.8
#
#    Fuel consumption per 100KM  Total fuel used  Number of wheels  \
# 0                         3.4         5101.462                 4
# 1                         5.6         4922.344                 4
# ...

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_reset=car_sales.sample(frac=1)

# %%
car_sales_reset
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 1   Honda    Red          87899      4   $5,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 9  Nissan  White          31600      4   $9,700.00
# 3     BMW  Black          11179      5  $22,000.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 0  Toyota  White         150043      4   $4,000.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
#selects only 20% of the data
car_sales_reset.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales_reset.reset_index(drop=True,inplace=True,)

# %%
car_sales_reset
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota   Blue          32549      3   $7,000.00
# 1  Toyota  White          60000      4   $6,250.00
# 2   Honda    Red          87899      4   $5,000.00
# 3  Nissan  White         213095      4   $3,500.00
# 4  Nissan  White          31600      4   $9,700.00
# 5     BMW  Black          11179      5  $22,000.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White         150043      4   $4,000.00
# 9  Toyota  Green          99213      4   $4,500.00

# %%
#apply function to a column
car_sales["Odometer (KM)"]=car_sales["Odometer (KM)"].apply(lambda x:x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White   62517.916667      4   $4,000.00
# 1   Honda    Red   36624.583333      4   $5,000.00
# 2  Toyota   Blue   13562.083333      3   $7,000.00
# 3     BMW  Black    4657.916667      5  $22,000.00
# 4  Nissan  White   88789.583333      4   $3,500.00
# 5  Toyota  Green   41338.750000      4   $4,500.00
# 6   Honda   Blue   19040.833333      4   $7,500.00
# 7   Honda   Blue   22807.500000      4   $7,000.00
# 8  Toyota  White   25000.000000      4   $6,250.00
# 9  Nissan  White   13166.666667      4   $9,700.00
